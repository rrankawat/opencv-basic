# %% [markdown]
# <a href="https://colab.research.google.com/github/rrankawat/opencv-basic/blob/main/1_Getting_Started.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Getting Started
#
#
# 1.   Import the OpenCV Model
# 2.   Load Images
# 3.   Display Images
# 4.   Save Images
# 5.   Getting Image Dimensions

# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %%
# Download and unzip images
# !gdown --id 1O2uCujErifjvK1ziRGssaQO9khI15g6q
# !unzip -qq images.zip
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1O2uCujErifjvK1ziRGssaQO9khI15g6q
# From (redirected): https://drive.google.com/uc?id=1O2uCujErifjvK1ziRGssaQO9khI15g6q&confirm=t&uuid=2d4f7792-68e8-4083-874a-83da883d60f8
# To: /content/images.zip
# 100% 29.6M/29.6M [00:00<00:00, 41.9MB/s]
# replace images/castara.jpeg? [y]es, [n]o, [A]ll, [N]one, [r]ename: N

# %%
# Loading images
image = cv2.imread('./images/flowers.jpeg')

# %%
# Displaying Images
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

# %%
# Function to display images
def imshow(title = "", image = None):
  plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
  plt.title(title)
  plt.show()

# %%
imshow("Displaying our First Image", image)

# %%
# Saving Images
cv2.imwrite('output.jpg', image)
# Out:
# True

# %%
# Displaying Image Dimensions
print(image.shape)
# Out:
# (960, 1280, 3)
